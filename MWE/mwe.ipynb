# %%
class Trie(object):
    def __init__(self,wd="",end=False):
        self.br={}; self.end=end
        if wd!="": self.addword(wd)
    def __repr__(self): # Uniquement pour les tests
        br=self.br.__repr__()
        m='E,' if self.end else ""
        return "T["+m+br+"]"

    def addword(self,wd):
        br=self.br
        if wd:
            c=wd[0]; rst=wd[1:] # Découpage essentiel
            if c not in br: 
                br[c]=Trie() # Nouvelle branche
            br[c].addword(rst)
        else: 
            self.end=True # Marqueur de la fin       

    def searchword(self,wd):
        if self.search(wd): 
            print(wd + " is in Trie")
            self.sufix(wd)
        else:
            print(wd + " is not in Trie")

    def sufix(self, wd):
        br = self.br
        for c in wd:
            br = br[c]

        print(br.words())

    def search(self,wd):
        br=self.br
        if wd:
            c=wd[0]; rst=wd[1:] # Découpage essentiel
            if c in br : 
                if len(rst) == 0: 
                    return True
                else : 
                    return br[c].search(rst)
            else : 
                return False
            

    def __getitem__(self,c):  # Objet émule une liste/dict.
        return self.br[c]

    # Renvoie tout les mots du dictionnaire
    def words(self):
        br=self.br
        l=[]
        for c in br:
            w=br[c].words() # Les suffixes du mot en question
            if w==[]: 
                x=[c] # Si vide
            else:
                x=[c+h for h in w] # Non vide. c à la tête
                if br[c].end: 
                    x+=[c] # Cas spécial ! 
            l+=x
        return l

# %%
t=Trie("abc") 
t.addword("abcef")
t.addword("apext")
t.addword("new")
t.addword("next")
t.addword("ape")
t.addword("bb")
rs=t.words()

print(t)
print(rs)
# Out:
# T[{'a': T[{'b': T[{'c': T[E,{'e': T[{'f': T[E,{}]}]}]}], 'p': T[{'e': T[E,{'x': T[{'t': T[E,{}]}]}]}]}], 'n': T[{'e': T[{'w': T[E,{}], 'x': T[{'t': T[E,{}]}]}]}], 'b': T[{'b': T[E,{}]}]}]
# ['abcef', 'abc', 'apext', 'ape', 'new', 'next', 'bb']

# %%
t.searchword("a")
# Out:
# a is in Trie
# ['bcef', 'bc', 'pext', 'pe']

# %%
f_in = open('mwe.csv', 'r')
Lines = f_in.readlines()
f_in.close() 

f_out = open("mwe_clean.txt", "a")

  
for line in Lines:
    linesplit = line.split(";")
    f_out.write(linesplit[1].replace('\"', '') + "\n")

f_out.close()

# %%
f = open('mwe_clean.txt', 'r')
lines = f.readlines()
f.close() 

t_mwe = Trie()

for line in lines: 
    t_mwe.addword(line)

# %%
t_mwe.searchword("petit")
# Out:
# petit is in Trie
# ['e vitesse\n', 'e vite\n', 'e vipère\n', 'e ville\n', 'e ville de province\n', 'e ville touristique\n', 'e ville fortifiée\n', 'e victoire\n', 'e vive\n', 'e violette\n', 'e violette>171870\n', 'e violette>171869\n', 'e vieille\n', 'e vieille>97156\n', 'e vieille>68467\n', 'e vinette\n', 'e vérole\n', 'e vérole volante (obs.)\n', 'e vérole par opposition à la grande vérole (syphilis)\n', 'e vénerie\n', 'e variole\n', 'e vache\n', 'e valise\n', 'e valise personnelle\n', 'e valve de la mitrale\n', 'e vallée\n', 'e vanne\n', 'e vague\n', 'e voile\n', 'e voiture\n', 'e voiture>117579\n', 'e voiture>123745\n', 'e voiture rouge\n', 'e voiture rouge>117579\n', 'e voiture rouge>123745\n', 'e voiture familiale\n', 'e voiture électrique\n', 'e voiture de malade\n', 'e voiture de foire\n', 'e voiture pour enfant\n', 'e voiture pour la ville\n', 'e voiture à 2 roues\n', 'e voix\n', 'e voûte pour statue\n', 'e